# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_index=pd.read_csv('economics_index_dataset.csv')

# %%
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
## drop unnecessary columns
df_index.drop(columns=["Unnamed: 0","year","month"],axis=1,inplace=True)

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
## check null values
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
## Let's do some visualization
import seaborn as sns
sns.pairplot(df_index)
# Out:
# C:\Users\raksh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raksh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\raksh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.924875     0.970316
# unemployment_rate      -0.924875           1.000000    -0.922908
# index_price             0.970316          -0.922908     1.000000

# %%
## Visualize the datapoints more closely
plt.scatter(df_index['interest_rate'],df_index['unemployment_rate'],color='r')
plt.xlabel("Interest Rate")
plt.ylabel("Unemployment Rate")
# Out:
# Text(0, 0.5, 'Unemployment Rate')

# %%
## independent anddependent feature
X=df_index.iloc[:,:-1]
Y=df_index.iloc[:,-1]

# %%
X
# Out:
#     interest_rate  unemployment_rate
# 0            2.75                5.3
# 1            2.50                5.3
# 2            2.50                5.3
# 3            2.50                5.3
# 4            2.50                5.4
# 5            2.50                5.6
# 6            2.50                5.5
# 7            2.25                5.5
# 8            2.25                5.5
# 9            2.25                5.6
# 10           2.00                5.7
# 11           2.00                5.9
# 12           2.00                6.0
# 13           1.75                5.9
# 14           1.75                5.8
# 15           1.75                6.1
# 16           1.75                6.2
# 17           1.75                6.1
# 18           1.75                6.1
# 19           1.75                6.1
# 20           1.75                5.9
# 21           1.75                5.9
# 22           1.75                6.2
# 23           1.75                6.1
# 24           1.75                6.1
# 25           1.75                6.0

# %%
Y
# Out:
# 0     1464
# 1     1394
# 2     1357
# 3     1293
# 4     1256
# 5     1254
# 6     1234
# 7     1195
# 8     1159
# 9     1167
# 10    1130
# 11    1075
# 12    1047
# 13     965
# 14     943
# 15     958
# 16     971
# 17     949
# 18     884
# 19     866
# 20     876
# 21     876
# 22     884
# 23     884
# 24     866
# 25     876
# Name: index_price, dtype: int64

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
import seaborn as sns

# %%
sns.regplot(x=df_index['interest_rate'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='interest_rate', ylabel='unemployment_rate'>

# %%
sns.regplot(x=df_index['index_price'],y=df_index['unemployment_rate'])
# Out:
# <Axes: xlabel='index_price', ylabel='unemployment_rate'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[ 1.36652042, -1.55375261],
#        [-0.85895569,  1.01331692],
#        [ 1.36652042, -0.59110154],
#        [ 1.36652042, -1.55375261],
#        [-0.11713032,  0.69243323],
#        [-0.85895569,  1.01331692],
#        [ 1.36652042, -1.55375261],
#        [ 1.36652042, -1.23286892],
#        [-0.85895569,  0.37154954],
#        [-0.85895569,  1.01331692],
#        [-0.85895569,  1.33420061],
#        [-0.85895569,  1.01331692],
#        [-0.85895569,  0.69243323],
#        [-0.85895569,  0.37154954],
#        [ 0.62469505, -0.91198523],
#        [-0.11713032, -0.27021785],
#        [-0.85895569,  0.05066585],
#        [-0.85895569,  1.01331692],
#        [ 1.36652042, -0.91198523]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## crossvalidation
from sklearn.model_selection import cross_val_score
validation_score=cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',cv=3)

# %%
np.mean(validation_score)
# Out:
# -2453.7310023819778

# %%
## prediction
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([1176.54766416,  869.03811739, 1401.72712028,  885.50413552,
#        1014.55988171, 1160.08164603,  918.43617178])

# %%
## performance metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 2975.932927816364
# 45.02983750026431
# 54.55211203809037

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9096471077779185

# %%
## display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

# %% [markdown]
# ## Assumptions

# %%
plt.scatter(y_test,y_pred)

# %%
residuals=y_test-y_pred
print(residuals)
# Out:
# 8     -17.547664
# 16    101.961883
# 0      62.272880
# 24    -19.504136
# 11     60.440118
# 9       6.918354
# 13     46.563828
# Name: index_price, dtype: float64

# %%
## plot residuals
sns.displot(residuals,kind='kde')
# Out:
# C:\Users\raksh\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
## scatter plot with respect to prediction and residuals
plt.scatter(y_pred,residuals)

# %%
## OLS Linear Regression
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,X_train).fit()

# %%
prediction=model.predict(X_test)
print(prediction)
# Out:
# [ 115.70555889 -191.80398788  340.88501501 -175.33796975  -46.28222356
#    99.23954076 -142.40593349]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            index_price   R-squared (uncentered):                   0.028
# Model:                            OLS   Adj. R-squared (uncentered):             -0.086
# Method:                 Least Squares   F-statistic:                             0.2453
# Date:                Tue, 02 Jul 2024   Prob (F-statistic):                       0.785
# Time:                        21:03:20   Log-Likelihood:                         -159.34
# No. Observations:                  19   AIC:                                      322.7
# Df Residuals:                      17   BIC:                                      324.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           133.1363    661.663      0.201      0.843   -1262.850    1529.123
# x2           -50.1209    661.663     -0.076      0.941   -1446.108    1345.866
# ==============================================================================
# Omnibus:                        2.948   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.229   Jarque-Bera (JB):                1.571
# Skew:                           0.407   Prob(JB):                        0.456
# Kurtosis:                       1.850   Cond. No.                         4.94
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\raksh\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
print(regression.coef_)
# Out:
# [133.13627784 -50.12085555]
